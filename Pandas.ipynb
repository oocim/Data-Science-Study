# %% [markdown]
# # Pandas

# %% [markdown]
# # Series

# %%
import pandas as pd

data = pd.Series([2,3,4,5], index =['a','b','c','d'])
print(data.values)
print(data.index)

# %%
data['a':'c']

# %%
grades_dict = {'A':4, 'B':3.5, 'C':3, 'D':2.5 }
grades = pd.Series(grades_dict)
grades.values

# %%
marks_dict = {'A':90, 'B':85, 'C':80, 'D':75 }
marks = pd.Series(marks_dict)
marks.values

# %% [markdown]
# # Data Frame

# %%
df = pd.DataFrame({'grades':grades,'marks':marks})
df

# %%
df.values

# %%
df.T

# %%
df.columns

# %%
df['scaled marks'] = 100*(df['marks']/90)
df

# %%
del df['scaled marks']
df

# %%
g = df[df['marks'] <85]
g

# %% [markdown]
# # Pandas Missing Values (NaN)

# %%
import pandas as pd
A = pd.DataFrame([{'a':1, 'b':4},{'b':5, 'c':7}])
A

# %%
B= A.fillna(0)
B
#Fills in missing values with value given

# %%
C = A.dropna
C
#Not recommended for a lot of missing values

# %% [markdown]
# # Pandas Indexing

# %%
data = pd.Series(['a','b','c'], index=[1,3,5])
print(data[1]) #explicit index
print(data[1:3]) #explicit index

# %%
data.loc[1:3] #explicit index

# %%
data.iloc[1:3] #implicit index

# %% [markdown]
# # CSV Files

# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
df = pd.read_csv('LCK_RegionalFinals_2024.csv',delimiter=";")

# %%
df.head()
# Out:
#      Player     Role Team Opponent_Team Opponent_Player        Date  Round  \
# 0      Zeus      TOP   T1            DK          kingen  12.09.2024      1
# 1      Oner   JUNGLE   T1            DK           Lucid  12.09.2024      1
# 2     Faker      MID   T1            DK       ShowMaker  12.09.2024      1
# 3  Gumayusi  ADCARRY   T1            DK          Aiming  12.09.2024      1
# 4     Keria  SUPPORT   T1            DK           Moham  12.09.2024      1
#
#    Day   Patch                 Stage  ...  Damage self mitigated  \
# 0    1  v14.16  Regional_Finals_2024  ...                  23062
# 1    1  v14.16  Regional_Finals_2024  ...                  35207
# 2    1  v14.16  Regional_Finals_2024  ...                  30650
# 3    1  v14.16  Regional_Finals_2024  ...                  24245
# 4    1  v14.16  Regional_Finals_2024  ...                  16456
#
#    Total Damage Shielded On Teammates  Time ccing others  Total Time CC Dealt  \
# ...

# %%
df.drop(['Patch','Stage'], axis=1,inplace=True)
df.head()
# Out:
#      Player     Role Team Opponent_Team Opponent_Player        Date  Round  \
# 0      Zeus      TOP   T1            DK          kingen  12.09.2024      1
# 1      Oner   JUNGLE   T1            DK           Lucid  12.09.2024      1
# 2     Faker      MID   T1            DK       ShowMaker  12.09.2024      1
# 3  Gumayusi  ADCARRY   T1            DK          Aiming  12.09.2024      1
# 4     Keria  SUPPORT   T1            DK           Moham  12.09.2024      1
#
#    Day  No_Game  all_Games  ...  Damage self mitigated  \
# 0    1        1          5  ...                  23062
# 1    1        1          5  ...                  35207
# 2    1        1          5  ...                  30650
# 3    1        1          5  ...                  24245
# 4    1        1          5  ...                  16456
#
#    Total Damage Shielded On Teammates Time ccing others Total Time CC Dealt  \
# 0                                   0                13                 350
# ...

# %%
df.rename(columns={'Opponent_Team':'Opp_Team', 'Opponent_Player':'Opp_Player','No_Game':'Games'},inplace=True)
df.head()
# Out:
#      Player     Role Team Opp_Team Opp_Player        Date  Round  Day  Games  \
# 0      Zeus      TOP   T1       DK     kingen  12.09.2024      1    1      1
# 1      Oner   JUNGLE   T1       DK      Lucid  12.09.2024      1    1      1
# 2     Faker      MID   T1       DK  ShowMaker  12.09.2024      1    1      1
# 3  Gumayusi  ADCARRY   T1       DK     Aiming  12.09.2024      1    1      1
# 4     Keria  SUPPORT   T1       DK      Moham  12.09.2024      1    1      1
#
#    all_Games  ...  Damage self mitigated  Total Damage Shielded On Teammates  \
# 0          5  ...                  23062                                   0
# 1          5  ...                  35207                                   0
# 2          5  ...                  30650                                   0
# 3          5  ...                  24245                                   0
# 4          5  ...                  16456                                 778
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format='%d.%m.%Y')
df.head()
# Out:
#      Player     Role Team Opp_Team Opp_Player       Date  Round  Day  Games  \
# 0      Zeus      TOP   T1       DK     kingen 2024-09-12      1    1      1
# 1      Oner   JUNGLE   T1       DK      Lucid 2024-09-12      1    1      1
# 2     Faker      MID   T1       DK  ShowMaker 2024-09-12      1    1      1
# 3  Gumayusi  ADCARRY   T1       DK     Aiming 2024-09-12      1    1      1
# 4     Keria  SUPPORT   T1       DK      Moham 2024-09-12      1    1      1
#
#    all_Games  ...  Damage self mitigated  Total Damage Shielded On Teammates  \
# 0          5  ...                  23062                                   0
# 1          5  ...                  35207                                   0
# 2          5  ...                  30650                                   0
# 3          5  ...                  24245                                   0
# 4          5  ...                  16456                                 778
#
# ...

# %%
df.describe()
# Out:
#                       Date       Round         Day       Games   all_Games  \
# count                  130  130.000000  130.000000  130.000000  130.000000
# mean   2024-09-13 00:00:00    1.384615    2.000000    2.769231    4.538462
# min    2024-09-12 00:00:00    1.000000    1.000000    1.000000    3.000000
# 25%    2024-09-12 00:00:00    1.000000    1.000000    2.000000    5.000000
# 50%    2024-09-13 00:00:00    1.000000    2.000000    3.000000    5.000000
# 75%    2024-09-14 00:00:00    2.000000    3.000000    4.000000    5.000000
# max    2024-09-14 00:00:00    2.000000    3.000000    5.000000    5.000000
# std                    NaN    0.488386    0.880451    1.372704    0.845910
#
#        Format  Game_of_day  Kills_Team  Turrets_Team  Dragon_Team  ...  \
# count   130.0   130.000000  130.000000    130.000000   130.000000  ...
# mean      5.0     2.769231   12.153846      5.730769     2.346154  ...
# min       5.0     1.000000    2.000000      0.000000     0.000000  ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130 entries, 0 to 129
# Data columns (total 79 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Player                              130 non-null    object
#  1   Role                                130 non-null    object
#  2   Team                                130 non-null    object
#  3   Opp_Team                            130 non-null    object
#  4   Opp_Player                          130 non-null    object
#  5   Date                                130 non-null    datetime64[ns]
#  6   Round                               130 non-null    int64
#  7   Day                                 130 non-null    int64
#  8   Games                               130 non-null    int64
#  9   all_Games                           130 non-null    int64
#  10  Format                              130 non-null    int64
# ...

# %%
df2 = df.groupby('Team')[['Physical Damage', 'Magic Damage', 'True Damage']].sum()
df2
# Out:
#       Physical Damage  Magic Damage  True Damage
# Team
# DK             176224        229957        24277
# FOX            106021        136026        12880
# KT             327666        264955        45450
# T1             364644        360139        54687

# %%
df2 = df.groupby(['Team','Date'])[['Physical Damage', 'Magic Damage', 'True Damage']].sum()
df2
# Out:
#                  Physical Damage  Magic Damage  True Damage
# Team Date
# DK   2024-09-12           176224        229957        24277
# FOX  2024-09-13           106021        136026        12880
# KT   2024-09-13           145739        119660        22388
#      2024-09-14           181927        145295        23062
# T1   2024-09-12           220425        164572        36126
#      2024-09-14           144219        195567        18561

# %%
df3 = df2[df2['True Damage'] > 15000]
df3
# Out:
#                  Physical Damage  Magic Damage  True Damage
# Team Date
# DK   2024-09-12           176224        229957        24277
# KT   2024-09-13           145739        119660        22388
#      2024-09-14           181927        145295        23062
# T1   2024-09-12           220425        164572        36126
#      2024-09-14           144219        195567        18561
